# %%
pip install dataframe-image
# Out:
# Requirement already satisfied: dataframe-image in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from dataframe-image) (4.10.0)
# Requirement already satisfied: aiohttp in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from dataframe-image) (3.8.1)
# Requirement already satisfied: pandas>=0.24 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from dataframe-image) (1.3.4)
# Requirement already satisfied: nbconvert>=5 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from dataframe-image) (6.1.0)
# Requirement already satisfied: requests in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from dataframe-image) (2.26.0)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from dataframe-image) (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->dataframe-image) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->dataframe-image) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->dataframe-image) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->dataframe-image) (1.20.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->dataframe-image) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->dataframe-image) (3.0.4)
# Requirement already satisfied: six in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from cycler>=0.10->matplotlib>=3.1->dataframe-image) (1.16.0)
# Requirement already satisfied: defusedxml in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (0.7.1)
# Requirement already satisfied: testpath in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (0.5.0)
# Requirement already satisfied: jinja2>=2.4 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (2.11.3)
# Requirement already satisfied: jupyter-core in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (4.9.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (2.10.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (1.4.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (5.1.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (0.5.3)
# Requirement already satisfied: bleach in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (0.1.2)
# Requirement already satisfied: traitlets>=5.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->dataframe-image) (5.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jinja2>=2.4->nbconvert>=5->dataframe-image) (1.1.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (1.10)
# Requirement already satisfied: pyzmq>=13 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (22.2.1)
# Requirement already satisfied: tornado>=4.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (6.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core->nbconvert>=5->dataframe-image) (228)
# Requirement already satisfied: ipython-genutils in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.4->nbconvert>=5->dataframe-image) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.4->nbconvert>=5->dataframe-image) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=5->dataframe-image) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=5->dataframe-image) (0.18.0)
# Requirement already satisfied: importlib-metadata in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=5->dataframe-image) (4.8.1)
# Requirement already satisfied: setuptools in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=5->dataframe-image) (58.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.24->dataframe-image) (2021.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (2.0.4)
# Requirement already satisfied: asynctest==0.13.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from aiohttp->dataframe-image) (3.10.0.2)
# Requirement already satisfied: idna>=2.0 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->dataframe-image) (3.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from beautifulsoup4->dataframe-image) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert>=5->dataframe-image) (0.5.1)
# Requirement already satisfied: packaging in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert>=5->dataframe-image) (21.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=5->dataframe-image) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from requests->dataframe-image) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ptene\anaconda3\envs\pythondata\lib\site-packages (from requests->dataframe-image) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies
import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from sqlalchemy import extract

# import dataframe_imagine
import dataframe_image as dfi

# %%
engine = create_engine("sqlite:///./Resources/hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# what are the tables in the hawaii.sqlite db
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
# from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
june_temps = session.query(Measurement).filter(extract('month', Measurement.date) == 6).all()
# june_temps

# %%
#  3. Convert the June temperatures to a list.
june_temps_list = [temp.tobs for temp in june_temps]
june_temps_list[:5]
# Out:
# [78.0, 76.0, 78.0, 76.0, 77.0]

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
june_temp_df = pd.DataFrame(june_temps_list, columns=['June Temps'])
june_temp_df
# Out:
#       June Temps
# 0           78.0
# 1           76.0
# 2           78.0
# 3           76.0
# 4           77.0
# ...          ...
# 1695        79.0
# 1696        74.0
# 1697        74.0
# 1698        76.0
# 1699        75.0
#
# [1700 rows x 1 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_temp_summary_stats = june_temp_df.describe()

# export as an image
dfi.export(june_temp_summary_stats, "Images/june_temp_summary_stats.png")

june_temp_summary_stats
# Out:
#         June Temps
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
dec_temps = session.query(Measurement).filter(extract('month', Measurement.date) == 12).all()
# dec_temps

# %%
# 7. Convert the December temperatures to a list.
dec_temps_list = [temp.tobs for temp in dec_temps]
dec_temps_list
# Out:
# [76.0,
#  74.0,
#  74.0,
#  64.0,
#  64.0,
#  67.0,
#  77.0,
#  66.0,
#  69.0,
#  68.0,
#  68.0,
#  71.0,
#  74.0,
#  67.0,
#  66.0,
#  69.0,
#  71.0,
0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  72.0,
#  74.0,
#  71.0,
#  70.0,
#  70.0,
#  69.0,
#  71.0,
#  70.0,
#  70.0,
#  72.0,
#  72.0,
#  72.0,
#  72.0,
#  72.0,
#  70.0,
#  66.0,
#  71.0,
#  68.0,
#  79.0,
#  76.0,
#  73.0,
#  75.0,
#  71.0,
#  76.0,
#  74.0,
#  73.0,
#  73.0,
#  74.0,
#  73.0,
#  72.0,
#  76.0,
#  75.0,
#  77.0,
#  74.0,
#  76.0,
#  75.0,
#  76.0,
#  73.0,
#  75.0,
#  73.0,
#  73.0,
#  74.0,
#  78.0,
#  78.0,
#  78.0,
#  75.0,
#  75.0,
#  75.0,
#  74.0,
#  77.0,
#  72.0,
#  72.0,
#  73.0,
#  71.0,
#  75.0,
#  76.0,
#  74.0,
#  75.0,
#  74.0,
#  75.0,
#  73.0,
#  72.0,
#  72.0,
#  75.0,
#  74.0,
#  74.0,
#  72.0,
#  73.0,
#  70.0,
#  76.0,
#  78.0,
#  76.0,
#  78.0,
#  74.0,
#  71.0,
#  78.0,
#  70.0,
#  74.0,
#  74.0,
#  75.0,
#  76.0,
#  78.0,
#  72.0,
#  73.0,
#  76.0,
#  72.0,
#  72.0,
#  78.0,
#  76.0,
#  76.0,
#  77.0,
#  79.0,
#  73.0,
#  79.0,
#  77.0,
#  78.0,
#  76.0,
#  78.0,
#  77.0,
#  79.0,
#  75.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  76.0,
#  75.0,
#  72.0,
#  75.0,
#  77.0,
#  75.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  72.0,
#  76.0,
#  75.0,
#  72.0,
#  72.0,
#  75.0,
#  69.0,
#  75.0,
#  74.0,
#  78.0,
#  77.0,
#  76.0,
#  72.0,
#  73.0,
#  74.0,
#  74.0,
#  74.0,
#  73.0,
#  73.0,
#  71.0,
#  72.0,
#  72.0,
#  75.0,
#  66.0,
#  66.0,
#  67.0,
#  76.0,
#  68.0,
#  69.0,
#  71.0,
#  70.0,
#  68.0,
#  66.0,
#  69.0,
#  69.0,
#  71.0,
#  72.0,
#  69.0,
#  72.0,
#  70.0,
#  76.0,
#  69.0,
#  71.0,
#  72.0,
#  71.0,
#  78.0,
#  73.0,
#  74.0,
#  68.0,
#  71.0,
#  76.0,
#  75.0,
#  74.0,
#  73.0,
#  73.0,
#  74.0,
#  69.0,
#  74.0,
#  72.0,
#  70.0,
#  67.0,
#  69.0,
#  73.0,
#  75.0,
#  74.0,
#  72.0,
#  71.0,
#  67.0,
#  74.0,
#  70.0,
#  70.0,
#  70.0,
#  71.0,
#  70.0,
#  71.0,
#  71.0,
#  68.0,
#  74.0,
#  75.0,
#  74.0,
#  77.0,
#  76.0,
#  77.0,
#  75.0,
#  76.0,
#  75.0,
#  77.0,
#  75.0,
#  77.0,
#  74.0,
#  78.0,
#  77.0,
#  76.0,
#  69.0,
#  70.0,
#  64.0,
#  75.0,
#  69.0,
#  65.0,
#  76.0,
#  81.0,
#  71.0,
#  71.0,
#  71.0,
#  82.0,
#  74.0,
#  75.0,
#  77.0,
#  74.0,
#  68.0,
#  72.0,
#  70.0,
#  68.0,
#  74.0,
#  71.0,
#  70.0,
#  70.0,
#  70.0,
#  68.0,
#  68.0,
#  68.0,
#  66.0,
#  71.0,
#  76.0,
#  73.0,
#  70.0,
#  68.0,
#  71.0,
#  71.0,
#  68.0,
#  71.0,
#  70.0,
#  73.0,
#  78.0,
#  76.0,
#  73.0,
#  74.0,
#  63.0,
#  72.0,
#  75.0,
#  74.0,
#  72.0,
#  68.0,
#  74.0,
#  73.0,
#  73.0,
#  72.0,
#  73.0,
#  72.0,
#  78.0,
#  74.0,
#  74.0,
#  78.0,
#  78.0,
#  61.0,
#  69.0,
#  65.0,
#  77.0,
#  67.0,
#  69.0,
#  75.0,
#  67.0,
#  71.0,
#  74.0,
#  66.0,
#  66.0,
#  77.0,
#  70.0,
#  73.0,
#  71.0,
#  71.0,
#  71.0,
#  67.0,
#  71.0,
#  74.0,
#  76.0,
#  72.0,
#  74.0,
#  75.0,
#  69.0,
#  69.0,
#  69.0,
#  75.0,
#  73.0,
#  73.0,
#  72.0,
#  72.0,
#  72.0,
#  74.0,
#  72.0,
#  73.0,
#  73.0,
#  73.0,
#  73.0,
#  74.0,
#  73.0,
#  71.0,
#  72.0,
#  73.0,
#  74.0,
#  72.0,
#  73.0,
#  73.0,
#  71.0,
#  73.0,
#  75.0,
#  71.0,
#  72.0,
#  73.0,
#  71.0,
#  65.0,
#  77.0,
#  72.0,
#  78.0,
#  71.0,
#  72.0,
#  71.0,
#  72.0,
#  76.0,
#  75.0,
#  75.0,
#  76.0,
#  73.0,
#  72.0,
#  74.0,
#  74.0,
#  74.0,
#  73.0,
#  77.0,
#  73.0,
#  70.0,
#  72.0,
#  76.0,
#  65.0,
#  74.0,
#  73.0,
#  77.0,
#  76.0,
#  69.0,
#  78.0,
#  76.0,
#  68.0,
#  76.0,
#  68.0,
#  79.0,
#  69.0,
#  64.0,
#  70.0,
#  69.0,
#  73.0,
#  70.0,
#  74.0,
#  76.0,
#  76.0,
#  69.0,
#  73.0,
#  73.0,
#  65.0,
#  70.0,
#  72.0,
#  72.0,
#  75.0,
#  74.0,
#  69.0,
#  73.0,
#  75.0,
#  76.0,
#  74.0,
#  73.0,
#  74.0,
#  71.0,
#  72.0,
#  73.0,
#  72.0,
#  72.0,
#  73.0,
#  72.0,
#  75.0,
#  76.0,
#  67.0,
#  69.0,
#  70.0,
#  75.0,
#  74.0,
#  71.0,
#  74.0,
#  71.0,
#  72.0,
#  74.0,
#  75.0,
#  73.0,
#  75.0,
#  76.0,
#  68.0,
#  71.0,
#  68.0,
#  66.0,
#  63.0,
#  62.0,
#  67.0,
#  68.0,
#  63.0,
#  56.0,
#  76.0,
#  75.0,
#  74.0,
#  76.0,
#  69.0,
#  71.0,
#  72.0,
#  74.0,
#  75.0,
#  72.0,
#  78.0,
#  69.0,
#  75.0,
#  75.0,
#  74.0,
#  74.0,
#  76.0,
#  73.0,
#  75.0,
#  75.0,
#  74.0,
#  79.0,
#  75.0,
#  76.0,
#  76.0,
#  69.0,
#  72.0,
#  76.0,
#  75.0,
#  75.0,
#  75.0,
#  70.0,
#  70.0,
#  74.0,
#  73.0,
#  72.0,
#  78.0,
#  67.0,
#  69.0,
#  71.0,
#  74.0,
#  63.0,
#  76.0,
#  76.0,
#  71.0,
#  76.0,
#  77.0,
#  73.0,
#  71.0,
#  78.0,
#  78.0,
#  75.0,
#  75.0,
#  72.0,
#  77.0,
#  72.0,
#  72.0,
#  71.0,
#  72.0,
#  74.0,
#  66.0,
#  61.0,
#  58.0,
#  60.0,
#  71.0,
#  65.0,
#  72.0,
#  70.0,
#  68.0,
#  67.0,
#  71.0,
#  65.0,
#  64.0,
#  65.0,
#  69.0,
#  70.0,
#  70.0,
#  68.0,
#  69.0,
#  71.0,
#  70.0,
#  71.0,
#  76.0,
#  71.0,
#  72.0,
#  73.0,
#  77.0,
#  67.0,
#  69.0,
#  72.0,
#  74.0,
#  71.0,
#  70.0,
#  68.0,
#  70.0,
#  66.0,
#  72.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  73.0,
#  71.0,
#  69.0,
#  73.0,
#  72.0,
#  71.0,
#  69.0,
#  70.0,
#  69.0,
#  70.0,
#  75.0,
#  71.0,
#  70.0,
#  ...]

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
dec_temp_df = pd.DataFrame(dec_temps_list, columns=['December Temps'])
dec_temp_df
# Out:
#       December Temps
# 0               76.0
# 1               74.0
# 2               74.0
# 3               64.0
# 4               64.0
# ...              ...
# 1512            71.0
# 1513            71.0
# 1514            69.0
# 1515            65.0
# 1516            65.0
#
# [1517 rows x 1 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_temp_summary_stats = dec_temp_df.describe()

# export as an image
dfi.export(dec_temp_summary_stats, "Images/dec_temp_summary_stats.png")

dec_temp_summary_stats
# Out:
#        December Temps
# count     1517.000000
# mean        71.041529
# std          3.745920
# min         56.000000
# 25%         69.000000
# 50%         71.000000
# 75%         74.000000
# max         83.000000

# %%
Dec_temp_summary_stats
